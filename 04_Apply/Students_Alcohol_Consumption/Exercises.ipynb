# %% [markdown]
# # Student Alcohol Consumption

# %% [markdown]
# ### Introduction:
#
# This time you will download a dataset from the UCI.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/Students_Alcohol_Consumption/student-mat.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called df.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/Students_Alcohol_Consumption/student-mat.csv')

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %% [markdown]
# ### Step 4. For the purpose of this exercise slice the dataframe from 'school' until the 'guardian' column

# %%
# got it on my own!
df.columns
new_df = df.loc[:, 'school':'guardian']
new_df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      reason guardian
# 0    course   mother
# ...

# %% [markdown]
# ### Step 5. Create a lambda function that will capitalize strings.

# %%
capitalize = lambda x : x.capitalize()
capitalize('booger')
# Out:
# 'Booger'

# %% [markdown]
# ### Step 6. Capitalize both Mjob and Fjob

# %%
new_df = new_df.convert_dtypes(infer_objects=True, convert_string=True)
new_df.dtypes

new_df.Mjob = new_df['Mjob'].apply(capitalize)
new_df.Mjob
new_df.Fjob = new_df['Fjob'].apply(capitalize)
new_df.Fjob
# Out:
# 0       Teacher
# 1         Other
# 2         Other
# 3      Services
# 4         Other
#          ...
# 390    Services
# 391    Services
# 392       Other
# 393       Other
# 394     At_home
# Name: Fjob, Length: 395, dtype: object

# %% [markdown]
# ### Step 7. Print the last elements of the data set.

# %%
new_df.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  Services  Services
# 391     MS   M   17       U     LE3       T     3     1  Services  Services
# 392     MS   M   21       R     GT3       T     1     1     Other     Other
# 393     MS   M   18       R     LE3       T     3     2  Services     Other
# 394     MS   M   19       U     LE3       T     1     1     Other   At_home
#
#      reason guardian
# 390  course    other
# 391  course   mother
# 392  course    other
# 393  course   mother
# 394  course   father

# %% [markdown]
# ### Step 8. Did you notice the original dataframe is still lowercase? Why is that? Fix it and capitalize Mjob and Fjob.

# %%
# already fixed in step 6

# %% [markdown]
# ### Step 9. Create a function called majority that returns a boolean value to a new column called legal_drinker (Consider majority as older than 17 years old)

# %%
def majority(x):
    if x <= 17:
        return False
    else:
        return True

# %%
# YES!!!! I figured it out all on my own!! (by RTFM)!!
new_df.insert(12, 'legal_drinker', new_df['age'].apply(majority))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [38], in <module>
# ----> 1 new_df.insert(12, 'legal_drinker', new_df['age'].apply(majority))
#
# File ~/Projects/pandas_exercises_clone/venv/lib/python3.9/site-packages/pandas/core/frame.py:4434, in DataFrame.insert(self, loc, column, value, allow_duplicates)
#    4428     raise ValueError(
#    4429         "Cannot specify 'allow_duplicates=True' when "
#    4430         "'self.flags.allows_duplicate_labels' is False."
#    4431     )
#    4432 if not allow_duplicates and column in self.columns:
#    4433     # Should this be a different kind of error??
# -> 4434     raise ValueError(f"cannot insert {column}, already exists")
#    4435 if not isinstance(loc, int):
#    4436     raise TypeError("loc must be int")
#
# ValueError: cannot insert legal_drinker, already exists

# %%
new_df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   At_home   Teacher
# 1       GP   F   17       U     GT3       T     1     1   At_home     Other
# 2       GP   F   15       U     LE3       T     1     1   At_home     Other
# 3       GP   F   15       U     GT3       T     4     2    Health  Services
# 4       GP   F   16       U     GT3       T     3     3     Other     Other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  Services  Services
# 391     MS   M   17       U     LE3       T     3     1  Services  Services
# 392     MS   M   21       R     GT3       T     1     1     Other     Other
# 393     MS   M   18       R     LE3       T     3     2  Services     Other
# 394     MS   M   19       U     LE3       T     1     1     Other   At_home
#
#      reason guardian  legal_drinker
# ...

# %% [markdown]
# ### Step 10. Multiply every number of the dataset by 10.
# ##### I know this makes no sense, don't forget it is just an exercise

# %%
new_df.dtypes

# grab all columns with integers (probalby a better way)
new_df.iloc[:, [2, 6, 7]]


# Yes!! I did this all on my own!! Feels so amazing!
# It's not quite the same as the how the solution does it or displays it,
# but I used my new found knowledge of .apply and lambda functions to pull it off.
x_ten = lambda x : x*10

times_ten_df = new_df.iloc[:, [2, 6, 7]].apply(x_ten)

# %%
new_df.iloc[:, [2, 6, 7]]
# Out:
#      age  Medu  Fedu
# 0     18     4     4
# 1     17     1     1
# 2     15     1     1
# 3     15     4     2
# 4     16     3     3
# ..   ...   ...   ...
# 390   20     2     2
# 391   17     3     1
# 392   21     1     1
# 393   18     3     2
# 394   19     1     1
#
# [395 rows x 3 columns]

# %%
times_ten_df
# Out:
#      age  Medu  Fedu
# 0    180    40    40
# 1    170    10    10
# 2    150    10    10
# 3    150    40    20
# 4    160    30    30
# ..   ...   ...   ...
# 390  200    20    20
# 391  170    30    10
# 392  210    10    10
# 393  180    30    20
# 394  190    10    10
#
# [395 rows x 3 columns]
